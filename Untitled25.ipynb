# %% [markdown]
# <a href="https://colab.research.google.com/github/laurindodumba/AULA-FUNDAMENTO-DE-INTELIGENCIA-ARTIFICIAL/blob/main/Untitled25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![img.png](data:image/png;base64,...)

# %% [markdown]
# # AULA DE INTELIGÊNCIA ARTIFICIAL

# %%
# Meu comentário

# %% [markdown]
# ```
# # Isto está formatado como código
#
# 1.   Item da lista
#
# *   Item da lista
# *   Item da lista
#
#
# 2.   Item da lista
#
#
# ```

# %%
print("Olá mundo")
